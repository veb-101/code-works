# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x = np.linspace(0, 10, 10)

# %%
y = np.sin(x)

# %%
# matplotlib inline

# %%
plt.plot(x, y)

# %%
plt.show()

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("Time")
plt.ylabel("Some function of time")
plt.title("My cool chart")
# Out:
# Text(0.5,1,'My cool chart')

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

# %%
import pandas as pd
A = pd.read_csv(r"C:\Users\batman-101\Desktop\code-works\machine_learning_examples-master\linear_regression_class\data_1d.csv",header=None).as_matrix()

# %%
x = A[:, 0]
y = A[:, 1]

# %%
plt.scatter(x, y)

# %%
x_line = np.linspace(0, 100, 100)
y_line = 2 * x_line + 1
plt.scatter(x_line, y_line)

# %%
plt.hist(x)
# Out:
# (array([ 10.,   9.,   5.,  13.,  10.,  10.,   8.,  16.,  10.,   9.]),
#  array([  3.21124861,  12.88597188,  22.56069515,  32.23541842,
#          41.91014169,  51.58486496,  61.25958823,  70.9343115 ,
#          80.60903477,  90.28375804,  99.95848131]),
#  <a list of 10 Patch objects>)

# %%
r = np.random.rand(10000)
plt.hist(r, bins=20)
# Out:
# (array([ 504.,  513.,  521.,  506.,  473.,  471.,  535.,  483.,  490.,
#          520.,  518.,  514.,  492.,  516.,  483.,  475.,  490.,  503.,
#          499.,  494.]),
#  array([  3.50798719e-06,   5.00013522e-02,   9.99991965e-02,
#           1.49997041e-01,   1.99994885e-01,   2.49992729e-01,
#           2.99990574e-01,   3.49988418e-01,   3.99986262e-01,
#           4.49984106e-01,   4.99981951e-01,   5.49979795e-01,
#           5.99977639e-01,   6.49975483e-01,   6.99973328e-01,
#           7.49971172e-01,   7.99969016e-01,   8.49966860e-01,
#           8.99964705e-01,   9.49962549e-01,   9.99960393e-01]),
#  <a list of 20 Patch objects>)

# %%
y_actual = 2 * x + 1
residuals = y - y_actual
plt.hist(residuals)
# Out:
# (array([  6.,   7.,  15.,  14.,  12.,  18.,  13.,   7.,   6.,   2.]),
#  array([ -9.78834827,  -7.57337797,  -5.35840768,  -3.14343738,
#          -0.92846708,   1.28650321,   3.50147351,   5.7164438 ,
#           7.9314141 ,  10.14638439,  12.36135469]),
#  <a list of 10 Patch objects>)

# %%
df = pd.read_csv(r"C:\Users\batman-101\Desktop\code-works\train.csv")

# %%
df.shape
# Out:
# (42000, 785)

# %%
M = df.as_matrix()

# %%
im =M[0,1:] # select the zeroth row and give all the columns except 0 since its not an pixel

# %%
im.shape
# Out:
# (784,)

# %%
im = im.reshape(28, 28)

# %%
plt.imshow(im)

# %%
M[0,0]
# Out:
# 1

# %%
plt.imshow(im,cmap="gray")

# %%
plt.imshow(255- im, cmap="gray")
